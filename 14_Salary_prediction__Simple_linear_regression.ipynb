# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreelakshmiamenon/Machine-learning-projects/blob/main/14_Salary_prediction__Simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/Salary_Data.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.tail()
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x1=df['YearsExperience'].tolist()
x1
# Out:
# [1.1,
#  1.3,
#  1.5,
#  2.0,
#  2.2,
#  2.9,
#  3.0,
#  3.2,
#  3.2,
#  3.7,
#  3.9,
#  4.0,
#  4.0,
#  4.1,
#  4.5,
#  4.9,
#  5.1,
#  5.3,
#  5.9,
#  6.0,
#  6.8,
#  7.1,
#  7.9,
#  8.2,
#  8.7,
#  9.0,
#  9.5,
#  9.6,
#  10.3,
#  10.5]

# %%
y1=df['Salary'].tolist()
y1
# Out:
# [39343.0,
#  46205.0,
#  37731.0,
#  43525.0,
#  39891.0,
#  56642.0,
#  60150.0,
#  54445.0,
#  64445.0,
#  57189.0,
#  63218.0,
#  55794.0,
#  56957.0,
#  57081.0,
#  61111.0,
#  67938.0,
#  66029.0,
#  83088.0,
#  81363.0,
#  93940.0,
#  91738.0,
#  98273.0,
#  101302.0,
#  113812.0,
#  109431.0,
#  105582.0,
#  116969.0,
#  112635.0,
#  122391.0,
#  121872.0]

# %%
plt.scatter(x1,y1)
plt.title('Salary prediction')
plt.xlabel('Year of experince')
plt.ylabel('Salary')
plt.xticks(x1)
plt.yticks(y1)
plt.show()

# %%
x=df.iloc[:,:-1]
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
x.ndim
# Out:
# 2

# %%
y.ndim
# Out:
# 1

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
#     YearsExperience
# 0               1.1
# 4               2.2
# 16              5.1
# 5               2.9
# 13              4.1
# 11              4.0
# 22              7.9
# 1               1.3
# 2               1.5
# 25              9.0
# 3               2.0
# 21              7.1
# 26              9.5
# 18              5.9
# 29             10.5
# 20              6.8
# 7               3.2
# 10              3.9
# 14              4.5
# 19              6.0
# 6               3.0

# %%
x_test
# Out:
#     YearsExperience
# 27              9.6
# 15              4.9
# 23              8.2
# 17              5.3
# 8               3.2
# 9               3.7
# 28             10.3
# 24              8.7
# 12              4.0

# %%
y_train
# Out:
# 0      39343.0
# 4      39891.0
# 16     66029.0
# 5      56642.0
# 13     57081.0
# 11     55794.0
# 22    101302.0
# 1      46205.0
# 2      37731.0
# 25    105582.0
# 3      43525.0
# 21     98273.0
# 26    116969.0
# 18     81363.0
# 29    121872.0
# 20     91738.0
# 7      54445.0
# 10     63218.0
# 14     61111.0
# 19     93940.0
# 6      60150.0
# Name: Salary, dtype: float64

# %%
y_test
# Out:
# 27    112635.0
# 15     67938.0
# 23    113812.0
# 17     83088.0
# 8      64445.0
# 9      57189.0
# 28    122391.0
# 24    109431.0
# 12     56957.0
# Name: Salary, dtype: float64

# %%
#model creation
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred                          #
# Out:
# array([115573.62288352,  71679.93878159, 102498.90847018,  75415.57147111,
#         55803.4998511 ,  60473.04071301, 122110.98009019, 107168.44933209,
#         63274.76523015])

# %%
y_test
# Out:
# 27    112635.0
# 15     67938.0
# 23    113812.0
# 17     83088.0
# 8      64445.0
# 9      57189.0
# 28    122391.0
# 24    109431.0
# 12     56957.0
# Name: Salary, dtype: float64

# %%
#To plot graph
plt.scatter(x_train,y_train,color='c')
plt.plot(x_test,y_pred,color='r')   #y=mx+c

# %%
print(model.predict([[8.5]]))
# Out:
# [105300.63298732]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#to find slope
print("Slope is: ",model.coef_)
# Out:
# Slope is:  [9339.08172382]

# %%
#to find the constant
print("Constant is: ",model.intercept_)
# Out:
# Constant is:  25918.438334893202

# %%
print(model.predict([[4.2]]))        #y=9339.081*4+25918.438=65142.567
# Out:
# [65142.58157492]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df1=pd.DataFrame({'Actual_value':y_test,'Predicted_value':y_pred,'Difference':y_test-y_pred})
df1
# Out:
#     Actual_value  Predicted_value    Difference
# 27      112635.0    115573.622884  -2938.622884
# 15       67938.0     71679.938782  -3741.938782
# 23      113812.0    102498.908470  11313.091530
# 17       83088.0     75415.571471   7672.428529
# 8        64445.0     55803.499851   8641.500149
# 9        57189.0     60473.040713  -3284.040713
# 28      122391.0    122110.980090    280.019910
# 24      109431.0    107168.449332   2262.550668
# 12       56957.0     63274.765230  -6317.765230

# %%
#performance evaluation
#MAE: Mean absolute error
#MSE: Mean square error
#RMSE: Root mean square error
#R_2 SCORE
#MAPE :Mean absolute percentage error

# %%
from sklearn.metrics import mean_absolute_error       #MAE
print("Error is: ",mean_absolute_error(y_test,y_pred))
# Out:
# Error is:  5161.328710400183

# %%
from sklearn.metrics import mean_absolute_percentage_error   #MAPE
print("Percentage error is: ",mean_absolute_percentage_error(y_test,y_pred))
# Out:
# Percentage error is:  0.06647907533756252

# %%
from sklearn.metrics import mean_squared_error     #MSE
print("Squared error is: ",mean_squared_error(y_test,y_pred))
# Out:
# Squared error is:  37784662.46621314

# %%
from sklearn.metrics import mean_squared_error   #RMSE
data=mean_squared_error(y_test,y_pred)
data
# Out:
# 37784662.46621314

# %%
sq=np.sqrt(data)
sq
# Out:
# 6146.92300799458

# %%
from sklearn.metrics import r2_score
print("R_2 score is: ",r2_score(y_test,y_pred))
# Out:
# R_2 score is:  0.9414466227178214
