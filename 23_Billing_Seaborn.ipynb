# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreelakshmiamenon/Machine-learning-projects/blob/main/23_Billing_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# To determine tip

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
#Correlation
df.corr()
# Out:
# <ipython-input-7-7e6697e05da5>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# Here, total_bill affects tip(0.67) more than size(0.48)

# %% [markdown]
# Heatmap

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-8-3dc3d7d5a074>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# Joint plot

# %%
sns.jointplot(x='tip',y='total_bill',data=df)

# %%
sns.jointplot(x='tip',y='size',data=df)

# %%
sns.jointplot(x='tip',y='size',data=df,kind='reg')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %%
sns.jointplot(x='tip',y='size',data=df,kind='hex')   #hexagonal

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %% [markdown]
# Pairplot

# %%
sns.pairplot(df)

# %%
#To plot object column
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='smoker')

# %%
sns.pairplot(df,hue='day')

# %%
sns.pairplot(df,hue='time')

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# Count plot

# %%
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='smoker',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='day',data=df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='time',data=df)
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.countplot(x='sex',data=df,hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='day',data=df,hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='smoker',data=df,hue='day')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(y='sex',data=df,hue='smoker')
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.countplot(y='day',data=df,hue='smoker')
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %% [markdown]
# Bar plot

# %%
sns.barplot(x='total_bill',y='sex',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
sns.boxplot(x='smoker',y='total_bill',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %% [markdown]
# Three lines are the three percentiles, Q1,Q2,Q3;
# Q1: 25 percentile
# Q2: 50 percentile
# Q3: 75 percentile
# Outliers: The circles above maximum(wrong format data).

# %% [markdown]
# 3,5,7,1,1,8,4,6
#
# To calculate percentiles:
# sort in ascending order: 1,1,3,4,5,6,7,8
# calculate median: 4+5/2=4.5  i.e. Q2:50 percentile
#
# 1,1,3,4     5,6,7,8
# Q1: 1+3/2=2  i.e. Q1:25 percentile
# Q3: 6+7/2=6.5   i.e. Q3: 75 percentile
#
# To calculate Quartile:
# IQR(Inter Quartile Range)
# Q3-Q1
# 6.5-2=4.5
#
# To calculate maximum outliers:
# Q3 + 1.5 IQR = 6.5+1.5*4.5 = 13.25
#
# To calculate minimum outliers:
# Q1 - 1.5 IQR = 2-1.5*4.5 = -4.75
