# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreelakshmiamenon/Machine-learning-projects/blob/main/16_Simple_linear_Regression_Height_weight_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/SOCR-HeightWeight.csv')
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331        112.9925
# 1          2        71.51521        136.4873
# 2          3        69.39874        153.0269
# 3          4        68.21660        142.3354
# 4          5        67.78781        144.2971
# ...      ...             ...             ...
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742
#
# [25000 rows x 3 columns]

# %%
df.dtypes
# Out:
# Index               int64
# Height(Inches)    float64
# Weight(Pounds)    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Index', 'Height(Inches)', 'Weight(Pounds)'], dtype='object')

# %%
df.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
df.tail()
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742

# %%
df.isna().sum()
# Out:
# Index             0
# Height(Inches)    0
# Weight(Pounds)    0
# dtype: int64

# %%
x1=df['Height(Inches)'].tolist()
x1
# Out:
# [65.78331,
#  71.51521,
#  69.39874,
#  68.2166,
#  67.78781,
#  68.69784,
#  69.80204,
#  70.01472,
#  67.90265,
#  66.78236,
#  66.48769,
#  67.62333,
#  68.30248,
#  67.11656,
#  68.27967,
#  71.0916,
#  66.461,
#  68.64927,
#  71.23033,
#  67.13118,
#  67.83379,
#  68.87881,
#  63.48115,
#  68.42187,
#  67.62804,
#  67.20864,
#  70.84235,
#  67.49434,
#  66.53401,
#  65.44098,
#  69.5233,
#  65.8132,
#  67.8163,
#  70.59505,
#  71.80484,
#  69.20613,
#  66.80368,
#  67.65893,
#  67.80701,
#  64.04535,
#  68.57463,
#  65.18357,
#  69.65814,
#  67.96731,
#  65.98088,
#  68.67249,
#  66.88088,
#  67.69868,
#  69.82117,
#  69.08817,
#  69.91479,
#  67.33182,
#  70.26939,
#  69.10344,
#  65.38356,
#  70.18447,
#  70.40617,
#  66.54376,
#  66.36418,
#  67.537,
#  66.50418,
#  68.99958,
#  68.30355,
#  67.01255,
#  70.80592,
#  68.21951,
#  69.05914,
#  67.73103,
#  67.21568,
#  67.36763,
#  65.27033,
#  70.84278,
#  69.92442,
#  64.28508,
#  68.2452,
#  66.35708,
#  68.36275,
# ...

# %%
y1=df['Weight(Pounds)'].tolist()
y1
# Out:
# [112.9925,
#  136.4873,
#  153.0269,
#  142.3354,
#  144.2971,
#  123.3024,
#  141.4947,
#  136.4623,
#  112.3723,
#  120.6672,
#  127.4516,
#  114.143,
#  125.6107,
#  122.4618,
#  116.0866,
#  139.9975,
#  129.5023,
#  142.9733,
#  137.9025,
#  124.0449,
#  141.2807,
#  143.5392,
#  97.90191,
#  129.5027,
#  141.8501,
#  129.7244,
#  142.4235,
#  131.5502,
#  108.3324,
#  113.8922,
#  103.3016,
#  120.7536,
#  125.7886,
#  136.2225,
#  140.1015,
#  128.7487,
#  141.7994,
#  121.2319,
#  131.3478,
#  106.7115,
#  124.3598,
#  124.8591,
#  139.6711,
#  137.3696,
#  106.4499,
#  128.7639,
#  145.6837,
#  116.819,
#  143.6215,
#  134.9325,
#  147.0219,
#  126.3285,
#  125.4839,
#  115.7084,
#  123.4892,
#  147.8926,
#  155.8987,
#  128.0742,
#  119.3701,
#  133.8148,
#  128.7325,
#  137.5453,
#  129.7604,
#  128.824,
#  135.3165,
#  109.6113,
#  142.4684,
#  132.749,
#  103.5275,
#  124.7299,
#  129.3137,
#  134.0175,
#  140.3969,
#  102.8351,
#  128.5214,
#  120.2991,
#  138.6036,
# ...

# %%
plt.scatter(x1,y1)
plt.title('Height-Weight graph')
plt.xlabel('Height(Inches)')
plt.ylabel('Weight(Pounds)')
plt.show()

# %%
x=df.iloc[:,1:-1]
x
# Out:
#        Height(Inches)
# 0            65.78331
# 1            71.51521
# 2            69.39874
# 3            68.21660
# 4            67.78781
# ...               ...
# 24995        69.50215
# 24996        64.54826
# 24997        64.69855
# 24998        67.52918
# 24999        68.87761
#
# [25000 rows x 1 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0        112.9925
# 1        136.4873
# 2        153.0269
# 3        142.3354
# 4        144.2971
#            ...
# 24995    118.0312
# 24996    120.1932
# 24997    118.2655
# 24998    132.2682
# 24999    124.8742
# Name: Weight(Pounds), Length: 25000, dtype: float64

# %%
x.ndim
# Out:
# 2

# %%
y.ndim
# Out:
# 1

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
#        Height(Inches)
# 4913         67.56772
# 9338         70.44212
# 24211        68.04343
# 18791        66.85592
# 16066        68.69408
# ...               ...
# 21575        67.48875
# 5390         66.92527
# 860          68.39347
# 15795        69.29711
# 23654        67.12804
#
# [17500 rows x 1 columns]

# %%
x_test
# Out:
#        Height(Inches)
# 6868         68.42447
# 24016        67.89663
# 9668         67.65922
# 13640        69.01299
# 14018        69.01055
# ...               ...
# 21156        67.75061
# 24654        68.06416
# 14592        65.10865
# 20160        70.12934
# 4731         65.15114
#
# [7500 rows x 1 columns]

# %%
y_train
# Out:
# 4913     130.5236
# 9338     135.0743
# 24211    114.9553
# 18791    143.7988
# 16066    121.5060
#            ...
# 21575    111.5242
# 5390     123.4431
# 860      120.9809
# 15795    135.6468
# 23654    122.7826
# Name: Weight(Pounds), Length: 17500, dtype: float64

# %%
y_test
# Out:
# 6868     134.2855
# 24016    111.9666
# 9668     135.9871
# 13640    126.3802
# 14018    100.1810
#            ...
# 21156    125.6399
# 24654    126.1776
# 14592    126.4611
# 20160    134.9922
# 4731     111.6275
# Name: Weight(Pounds), Length: 7500, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([128.37941434, 126.75972205, 126.0312226 , ..., 118.20472487,
#        133.61085719, 118.33510667])

# %%
y_test
# Out:
# 6868     134.2855
# 24016    111.9666
# 9668     135.9871
# 13640    126.3802
# 14018    100.1810
#            ...
# 21156    125.6399
# 24654    126.1776
# 14592    126.4611
# 20160    134.9922
# 4731     111.6275
# Name: Weight(Pounds), Length: 7500, dtype: float64

# %%
#To plot graph
plt.scatter(x_train,y_train,color='c')
plt.plot(x_test,y_pred,color='r')   #y=mx+c

# %%
#to find slope
print("Slope is: ",model.coef_)
# Out:
# Slope is:  [3.06852889]

# %%
#to find the constant
print("Constant is: ",model.intercept_)
# Out:
# Constant is:  -81.58304861164356

# %%
df1=pd.DataFrame({'Actual_value':y_test,'Predicted_value':y_pred,'Difference':y_test-y_pred})
df1
# Out:
#        Actual_value  Predicted_value  Difference
# 6868       134.2855       128.379414    5.906086
# 24016      111.9666       126.759722  -14.793122
# 9668       135.9871       126.031223    9.955877
# 13640      126.3802       130.185305   -3.805105
# 14018      100.1810       130.177818  -29.996818
# ...             ...              ...         ...
# 21156      125.6399       126.311655   -0.671755
# 24654      126.1776       127.273793   -1.096193
# 14592      126.4611       118.204725    8.256375
# 20160      134.9922       133.610857    1.381343
# 4731       111.6275       118.335107   -6.707607
#
# [7500 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error       #MAE
print("Error is: ",mean_absolute_error(y_test,y_pred))
# Out:
# Error is:  8.038079092885338

# %%
from sklearn.metrics import mean_absolute_percentage_error   #MAPE
print("Percentage error is: ",mean_absolute_percentage_error(y_test,y_pred))
# Out:
# Percentage error is:  0.06435694448021587

# %%
from sklearn.metrics import mean_squared_error     #MSE
print("Squared error is: ",mean_squared_error(y_test,y_pred))
# Out:
# Squared error is:  102.00655311790318

# %%
from sklearn.metrics import mean_squared_error   #RMSE
data=mean_squared_error(y_test,y_pred)
data
# Out:
# 102.00655311790318

# %%
sq=np.sqrt(data)
sq
# Out:
# 10.099829360830963

# %%
from sklearn.metrics import r2_score
print("R_2 score is: ",r2_score(y_test,y_pred))
# Out:
# R_2 score is:  0.25961263876058704
